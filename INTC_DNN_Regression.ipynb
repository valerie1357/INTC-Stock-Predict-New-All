# %%
# Date is converted into special data type of pandas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5890 entries, 0 to 5889
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5890 non-null   datetime64[ns]
#  1   Open       5890 non-null   float64
#  2   High       5890 non-null   float64
#  3   Low        5890 non-null   float64
#  4   Close      5890 non-null   float64
#  5   Adj Close  5890 non-null   float64
#  6   Volume     5890 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 322.2 KB

# %%
new_df=df.iloc[:,[0,4]].copy()
new_df
# Out:
#            Date      Close
# 0    2000-01-03  43.500000
# 1    2000-01-04  41.468750
# 2    2000-01-05  41.812500
# 3    2000-01-06  39.375000
# 4    2000-01-07  41.000000
# ...         ...        ...
# 5885 2023-05-24  29.000000
# 5886 2023-05-25  27.400000
# 5887 2023-05-26  29.000000
# 5888 2023-05-30  29.990000
# 5889 2023-05-31  31.440001
#
# [5890 rows x 2 columns]

# %%
# View descriptive statistics of target variable
# Pandas will automatically ignore date if the correct data type has been converted
new_df_describe = new_df.describe()
np.round(new_df_describe, 2)

print('\nSkewness for Close : ',stats.skew(new_df['Close']))
print('\nKurtosis for Close : ',stats.kurtosis(new_df['Close']))

new_df_describe
#new_df_describe.to_csv('new_df_close.csv')
# Out:
# Skewness for Close :  0.9646594141504498
#
# Kurtosis for Close :  -0.03289231336871712
#              Close
# count  5890.000000
# mean     31.987438
# std      13.249626
# min      12.080000
# 25%      21.792500
# 50%      27.600000
# 75%      37.209999
# max      74.875000

# %%
# Y
sns.set_theme()
fig = plt.figure(figsize=(6,4),dpi=200)
sns.histplot(new_df['Close'], kde=True, stat="density", color='#458B74');
fig = plt.figure(figsize=(6,4),dpi=200)
res = stats.probplot(new_df['Close'], plot=plt)

# %%
# Plot Close and its corresponding date
# Figure setting
plt.figure(figsize=(25,10),dpi=300)
plt.title('INTC Closing Price From January 2000 to May 2023', weight='bold', fontsize=26)
plt.xlabel('Date', weight='bold', fontsize=24)
plt.ylabel('Close Price', weight='bold', fontsize=24)

# Actual by predicted plot
plt.plot(new_df['Date'],new_df['Close'], marker='.')

# Set the axis
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid('on')
plt.show()

# %% [markdown]
# # 2. Creating time lags as predictor variables

# %% [markdown]
# # Important!: Be caution when dealing with time-series data

# %% [markdown]
# python do have various packages and function that can deal with time-series data with ease, however, make sure that you understand the fundamental first!

# %%
# Create 3 lags
new_df['Lag_1']=new_df['Close'].shift(1).copy()
new_df['Lag_2']=new_df['Close'].shift(2).copy()
new_df['Lag_3']=new_df['Close'].shift(3).copy()
new_df
# Out:
#            Date      Close     Lag_1      Lag_2      Lag_3
# 0    2000-01-03  43.500000       NaN        NaN        NaN
# 1    2000-01-04  41.468750  43.50000        NaN        NaN
# 2    2000-01-05  41.812500  41.46875  43.500000        NaN
# 3    2000-01-06  39.375000  41.81250  41.468750  43.500000
# 4    2000-01-07  41.000000  39.37500  41.812500  41.468750
# ...         ...        ...       ...        ...        ...
# 5885 2023-05-24  29.000000  29.51000  30.280001  29.930000
# 5886 2023-05-25  27.400000  29.00000  29.510000  30.280001
# 5887 2023-05-26  29.000000  27.40000  29.000000  29.510000
# 5888 2023-05-30  29.990000  29.00000  27.400000  29.000000
# 5889 2023-05-31  31.440001  29.99000  29.000000  27.400000
#
# [5890 rows x 5 columns]

# %%
# Drop out missing values and rest index
clean_df=new_df.dropna(axis=0, how='any').copy()
clean_df=clean_df.reset_index(drop=True)
clean_df
#clean_df.to_csv('new_clean_df.csv')
# Out:
#            Date      Close     Lag_1      Lag_2      Lag_3
# 0    2000-01-06  39.375000  41.81250  41.468750  43.500000
# 1    2000-01-07  41.000000  39.37500  41.812500  41.468750
# 2    2000-01-10  42.875000  41.00000  39.375000  41.812500
# 3    2000-01-11  44.843750  42.87500  41.000000  39.375000
# 4    2000-01-12  45.625000  44.84375  42.875000  41.000000
# ...         ...        ...       ...        ...        ...
# 5882 2023-05-24  29.000000  29.51000  30.280001  29.930000
# 5883 2023-05-25  27.400000  29.00000  29.510000  30.280001
# 5884 2023-05-26  29.000000  27.40000  29.000000  29.510000
# 5885 2023-05-30  29.990000  29.00000  27.400000  29.000000
# 5886 2023-05-31  31.440001  29.99000  29.000000  27.400000
#
# [5887 rows x 5 columns]

# %%
# Export the data
#clean_df.to_csv('D:/data_analysis/PyExport/Rainfall_Lags.csv',index=False, header=True)
# Colab
#clean_df.to_csv('Rainfall_Lags.csv',index=False, header=True)

# %% [markdown]
# # 3. Data preprocessing under time-series structure

# %% [markdown]
# A total of N=5887 are in the data set. In this practice, we will use the last three years of data as the testing set

# %%
# Train data
Forecast_train_data=clean_df.iloc[0:4525,:].copy()
Forecast_train_data
# Out:
#            Date      Close      Lag_1      Lag_2      Lag_3
# 0    2000-01-06  39.375000  41.812500  41.468750  43.500000
# 1    2000-01-07  41.000000  39.375000  41.812500  41.468750
# 2    2000-01-10  42.875000  41.000000  39.375000  41.812500
# 3    2000-01-11  44.843750  42.875000  41.000000  39.375000
# 4    2000-01-12  45.625000  44.843750  42.875000  41.000000
# ...         ...        ...        ...        ...        ...
# 4520 2017-12-22  46.700001  46.759998  47.560001  47.040001
# 4521 2017-12-26  46.080002  46.700001  46.759998  47.560001
# 4522 2017-12-27  46.110001  46.080002  46.700001  46.759998
# 4523 2017-12-28  46.220001  46.110001  46.080002  46.700001
# 4524 2017-12-29  46.160000  46.220001  46.110001  46.080002
#
# [4525 rows x 5 columns]

# %%
# Test data
Forecast_test_data=clean_df.iloc[4525:4525+1362,:].copy()
Forecast_test_data
# Out:
#            Date      Close      Lag_1      Lag_2      Lag_3
# 4525 2018-01-02  46.849998  46.160000  46.220001  46.110001
# 4526 2018-01-03  45.259998  46.849998  46.160000  46.220001
# 4527 2018-01-04  44.430000  45.259998  46.849998  46.160000
# 4528 2018-01-05  44.740002  44.430000  45.259998  46.849998
# 4529 2018-01-08  44.740002  44.740002  44.430000  45.259998
# ...         ...        ...        ...        ...        ...
# 5882 2023-05-24  29.000000  29.510000  30.280001  29.930000
# 5883 2023-05-25  27.400000  29.000000  29.510000  30.280001
# 5884 2023-05-26  29.000000  27.400000  29.000000  29.510000
# 5885 2023-05-30  29.990000  29.000000  27.400000  29.000000
# 5886 2023-05-31  31.440001  29.990000  29.000000  27.400000
#
# [1362 rows x 5 columns]

# %% [markdown]
# # 4. Prepare time-series data for train/validation structure manually

# %% [markdown]
# Here we have a total of 18 years of data in training data set that are ready to be further splitted into training and validation data set

# %% [markdown]
# # Rolling window

# %%
# Rolling 1
Rol_training_1=Forecast_train_data.iloc[0:2260,:].copy()
Rol_val_1=Forecast_train_data.iloc[2260:2260+756,:].copy()

# Rolling 2
Rol_training_2=Forecast_train_data.iloc[749:3016,:].copy()
Rol_val_2=Forecast_train_data.iloc[3016:3016+754,:].copy()

# Rolling 3
Rol_training_3=Forecast_train_data.iloc[1504:3770,:].copy()
Rol_val_3=Forecast_train_data.iloc[3770:3770+775,:].copy()

# %% [markdown]
# # 5. Set dependent variable(Close or target) & independent variable(X)

# %%
# Rolling 1
#set x (make prediction)
# Train
x_train = Rol_training_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler = MinMaxScaler(feature_range=(0, 1))
scalingT = MMscaler.fit_transform(x_train)
scaled_x_train = pd.DataFrame(data=scalingT)
scaled_x_train.columns = ['Lag_1','Lag_2','Lag_3']

# Validation
x_val = Rol_val_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler = MinMaxScaler(feature_range=(0, 1))
scalingV = MMscaler.fit_transform(x_val)
scaled_x_val = pd.DataFrame(data=scalingV)
scaled_x_val.columns = ['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train = Rol_training_1['Close'].copy()
y_val = Rol_val_1['Close'].copy()

# %% [markdown]
# # 6. Creating Net

# %%
# Quick recap: Total of 12 features in the data set
scaled_x_train.head()
# Out:
#       Lag_1     Lag_2     Lag_3
# 0  0.472224  0.466737  0.499162
# 1  0.433315  0.472224  0.466737
# 2  0.459255  0.433315  0.472224
# 3  0.489185  0.459255  0.433315
# 4  0.520612  0.489185  0.459255

# %%
# Tips: Using shape to call the amount of features in the data set
input_features=scaled_x_train.shape[1]
print('Amount of features:',input_features)
# Out:
# Amount of features: 3

# %% [markdown]
# # Important: Define customized loss function (RMSE)

# %%
from keras.losses import mse
from keras.backend import sqrt

def my_RMSE(y_true, y_pred):
    return sqrt(mse(y_true, y_pred))

# Register custom object
#from keras.utils.generic_utils import get_custom_objects for pc
#from tensorflow.keras.saving import get_custom_objects
from keras.utils import get_custom_objects
get_custom_objects().update({'my_RMSE': my_RMSE})

# %% [markdown]
# Note: As far as I know when I'm preparing this in-class material, keras does not have a built-in RMSE function. Rumor has it that a RMSE function is hidden in the latest version, however it needs to be confirmed. For instance, defining RMSE ourself is not difficult, just don't forget to register our custom functions.

# %% [markdown]
# # Sequential style coding for creating net

# %%
# Create the model (Six Hidden)
clear.clear_session()
model=Sequential()

# First layer
model.add(Dense(units=100, input_dim=3))
#model.add(Dropout(0.5))

# Hidden layer
model.add(Dense(units=100, activation='tanh')) # 120, 100
model.add(Dropout(0.5))
model.add(Dense(units=100, activation='tanh')) # 120, 100
model.add(Dropout(0.5))
model.add(Dense(units=50, activation='tanh')) # 80, 50
model.add(Dropout(0.5))
model.add(Dense(units=50, activation='tanh')) # 80, 50
model.add(Dropout(0.5))
model.add(Dense(units=10, activation='tanh')) # 40, 10
model.add(Dropout(0.5))
model.add(Dense(units=10, activation='tanh')) # 40 10
model.add(Dropout(0.5))

# Output layer
model.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01, beta_1=0.9, beta_2 = 0.999, epsilon = 1e-8)
model.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               400
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 50)                5050
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_5 (Dense)             (None, 10)                510
#
#  dropout_4 (Dropout)         (None, 10)                0
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dropout_5 (Dropout)         (None, 10)                0
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 28,831
# Trainable params: 28,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create the model (Three Hidden)
clear.clear_session()
model3=Sequential()

# First layer
model3.add(Dense(units=100, input_dim=3))
#model.add(Dropout(0.5))

# Hidden layer
model3.add(Dense(units=100, activation='tanh')) # 120, 100
model3.add(Dropout(0.5))

model3.add(Dense(units=50, activation='tanh')) # 80, 50
model3.add(Dropout(0.5))

model3.add(Dense(units=10, activation='tanh')) # 40, 10
model3.add(Dropout(0.5))


# Output layer
model3.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01, beta_1=0.9, beta_2 = 0.999, epsilon = 1e-8)
model3.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               400
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 10)                510
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 16,071
# Trainable params: 16,071
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note: Remember to clear the session or else some of the left neurans may cause trouble while fitting

# %% [markdown]
# # 7. Fit the model (train/validation)

# %%
# 7.1 Store in the history for more useful information
history=model3.fit(scaled_x_train, y_train, epochs=250, batch_size=128,verbose=1,validation_data=(scaled_x_val, y_val))
# Out:
# Epoch 1/250
# 18/18 [==============================] - 0s 5ms/step - loss: 23.2930 - mean_absolute_percentage_error: 83.8001 - val_loss: 14.4983 - val_mean_absolute_percentage_error: 71.9359
# Epoch 2/250
# 18/18 [==============================] - 0s 2ms/step - loss: 20.8432 - mean_absolute_percentage_error: 73.5418 - val_loss: 12.4294 - val_mean_absolute_percentage_error: 61.3360
# Epoch 3/250
# 18/18 [==============================] - 0s 2ms/step - loss: 18.8231 - mean_absolute_percentage_error: 65.1644 - val_loss: 10.3886 - val_mean_absolute_percentage_error: 50.8798
# Epoch 4/250
# 18/18 [==============================] - 0s 2ms/step - loss: 16.7079 - mean_absolute_percentage_error: 56.5300 - val_loss: 8.3712 - val_mean_absolute_percentage_error: 40.5432
# Epoch 5/250
# 18/18 [==============================] - 0s 2ms/step - loss: 14.8983 - mean_absolute_percentage_error: 49.2180 - val_loss: 6.4811 - val_mean_absolute_percentage_error: 30.9844
# Epoch 6/250
# 18/18 [==============================] - 0s 2ms/step - loss: 13.2185 - mean_absolute_percentage_error: 42.6974 - val_loss: 4.8761 - val_mean_absolute_percentage_error: 23.2442
# Epoch 7/250
# 18/18 [==============================] - 0s 2ms/step - loss: 11.8959 - mean_absolute_percentage_error: 37.7927 - val_loss: 3.7255 - val_mean_absolute_percentage_error: 18.1624
# Epoch 8/250
# 18/18 [==============================] - 0s 2ms/step - loss: 11.0912 - mean_absolute_percentage_error: 35.1036 - val_loss: 2.8568 - val_mean_absolute_percentage_error: 14.4864
# Epoch 9/250
# 18/18 [==============================] - 0s 2ms/step - loss: 10.2617 - mean_absolute_percentage_error: 32.6369 - val_loss: 2.2578 - val_mean_absolute_percentage_error: 12.0844
# Epoch 10/250
# 18/18 [==============================] - 0s 2ms/step - loss: 10.0172 - mean_absolute_percentage_error: 32.1392 - val_loss: 2.0819 - val_mean_absolute_percentage_error: 11.7411
# Epoch 11/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.8992 - mean_absolute_percentage_error: 32.1470 - val_loss: 2.1536 - val_mean_absolute_percentage_error: 12.5033
# Epoch 12/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.6453 - mean_absolute_percentage_error: 31.5063 - val_loss: 2.3174 - val_mean_absolute_percentage_error: 13.5606
# Epoch 13/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.6536 - mean_absolute_percentage_error: 31.7995 - val_loss: 2.5298 - val_mean_absolute_percentage_error: 14.8025
# Epoch 14/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.6168 - mean_absolute_percentage_error: 32.1291 - val_loss: 2.7339 - val_mean_absolute_percentage_error: 15.9585
# Epoch 15/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.5397 - mean_absolute_percentage_error: 31.8392 - val_loss: 2.8857 - val_mean_absolute_percentage_error: 16.8006
# Epoch 16/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.7630 - mean_absolute_percentage_error: 32.8049 - val_loss: 2.9771 - val_mean_absolute_percentage_error: 17.3017
# Epoch 17/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4551 - mean_absolute_percentage_error: 31.6516 - val_loss: 3.0905 - val_mean_absolute_percentage_error: 17.9205
# Epoch 18/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4961 - mean_absolute_percentage_error: 31.9506 - val_loss: 3.1227 - val_mean_absolute_percentage_error: 18.0954
# Epoch 19/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.6061 - mean_absolute_percentage_error: 32.3018 - val_loss: 3.1416 - val_mean_absolute_percentage_error: 18.1981
# Epoch 20/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4739 - mean_absolute_percentage_error: 31.7226 - val_loss: 3.1564 - val_mean_absolute_percentage_error: 18.2779
# Epoch 21/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.6572 - mean_absolute_percentage_error: 32.7298 - val_loss: 3.2217 - val_mean_absolute_percentage_error: 18.6317
# Epoch 22/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4943 - mean_absolute_percentage_error: 32.0230 - val_loss: 3.2301 - val_mean_absolute_percentage_error: 18.6768
# Epoch 23/250
# 18/18 [==============================] - 0s 3ms/step - loss: 9.4736 - mean_absolute_percentage_error: 31.7102 - val_loss: 3.2194 - val_mean_absolute_percentage_error: 18.6192
# Epoch 24/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.6076 - mean_absolute_percentage_error: 32.2734 - val_loss: 3.1909 - val_mean_absolute_percentage_error: 18.4650
# Epoch 25/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.5263 - mean_absolute_percentage_error: 31.8093 - val_loss: 3.1978 - val_mean_absolute_percentage_error: 18.5021
# Epoch 26/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4999 - mean_absolute_percentage_error: 31.9485 - val_loss: 3.1828 - val_mean_absolute_percentage_error: 18.4209
# Epoch 27/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4398 - mean_absolute_percentage_error: 31.6777 - val_loss: 3.1487 - val_mean_absolute_percentage_error: 18.2364
# Epoch 28/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3226 - mean_absolute_percentage_error: 31.0741 - val_loss: 3.1075 - val_mean_absolute_percentage_error: 18.0127
# Epoch 29/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4617 - mean_absolute_percentage_error: 31.6353 - val_loss: 3.1304 - val_mean_absolute_percentage_error: 18.1369
# Epoch 30/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4266 - mean_absolute_percentage_error: 31.5661 - val_loss: 3.2775 - val_mean_absolute_percentage_error: 18.9332
# Epoch 31/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3722 - mean_absolute_percentage_error: 31.5248 - val_loss: 3.2745 - val_mean_absolute_percentage_error: 18.9169
# Epoch 32/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4333 - mean_absolute_percentage_error: 31.5148 - val_loss: 3.3076 - val_mean_absolute_percentage_error: 19.0956
# Epoch 33/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3428 - mean_absolute_percentage_error: 31.5167 - val_loss: 3.2547 - val_mean_absolute_percentage_error: 18.8100
# Epoch 34/250
# 18/18 [==============================] - 0s 3ms/step - loss: 9.4471 - mean_absolute_percentage_error: 31.7120 - val_loss: 3.2966 - val_mean_absolute_percentage_error: 19.0361
# Epoch 35/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4391 - mean_absolute_percentage_error: 31.7446 - val_loss: 3.3180 - val_mean_absolute_percentage_error: 19.1513
# Epoch 36/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2309 - mean_absolute_percentage_error: 31.0961 - val_loss: 3.3236 - val_mean_absolute_percentage_error: 19.1819
# Epoch 37/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3645 - mean_absolute_percentage_error: 31.3797 - val_loss: 3.3308 - val_mean_absolute_percentage_error: 19.2206
# Epoch 38/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2172 - mean_absolute_percentage_error: 30.5762 - val_loss: 3.3484 - val_mean_absolute_percentage_error: 19.3148
# Epoch 39/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2617 - mean_absolute_percentage_error: 31.0959 - val_loss: 3.3201 - val_mean_absolute_percentage_error: 19.1628
# Epoch 40/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3714 - mean_absolute_percentage_error: 31.4599 - val_loss: 3.1955 - val_mean_absolute_percentage_error: 18.4896
# Epoch 41/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2379 - mean_absolute_percentage_error: 30.8616 - val_loss: 3.1801 - val_mean_absolute_percentage_error: 18.4063
# Epoch 42/250
# 18/18 [==============================] - 0s 3ms/step - loss: 9.3249 - mean_absolute_percentage_error: 31.4603 - val_loss: 3.2364 - val_mean_absolute_percentage_error: 18.7110
# Epoch 43/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2389 - mean_absolute_percentage_error: 30.9032 - val_loss: 3.2994 - val_mean_absolute_percentage_error: 19.0512
# Epoch 44/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3515 - mean_absolute_percentage_error: 31.3158 - val_loss: 3.2611 - val_mean_absolute_percentage_error: 18.8445
# Epoch 45/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.1743 - mean_absolute_percentage_error: 30.8174 - val_loss: 3.1883 - val_mean_absolute_percentage_error: 18.4507
# Epoch 46/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2189 - mean_absolute_percentage_error: 30.8595 - val_loss: 3.2550 - val_mean_absolute_percentage_error: 18.8117
# Epoch 47/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2181 - mean_absolute_percentage_error: 30.7500 - val_loss: 3.2919 - val_mean_absolute_percentage_error: 19.0109
# Epoch 48/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.1788 - mean_absolute_percentage_error: 30.7084 - val_loss: 3.3089 - val_mean_absolute_percentage_error: 19.1023
# Epoch 49/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2614 - mean_absolute_percentage_error: 31.1305 - val_loss: 3.3059 - val_mean_absolute_percentage_error: 19.0862
# Epoch 50/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0573 - mean_absolute_percentage_error: 30.2443 - val_loss: 3.3395 - val_mean_absolute_percentage_error: 19.2672
# Epoch 51/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3379 - mean_absolute_percentage_error: 31.2167 - val_loss: 3.3226 - val_mean_absolute_percentage_error: 19.1764
# Epoch 52/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9959 - mean_absolute_percentage_error: 29.7369 - val_loss: 3.2854 - val_mean_absolute_percentage_error: 18.9755
# Epoch 53/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.1190 - mean_absolute_percentage_error: 30.6858 - val_loss: 3.3619 - val_mean_absolute_percentage_error: 19.3875
# Epoch 54/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.3135 - mean_absolute_percentage_error: 31.4044 - val_loss: 3.3399 - val_mean_absolute_percentage_error: 19.2694
# Epoch 55/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.2045 - mean_absolute_percentage_error: 30.7555 - val_loss: 3.4106 - val_mean_absolute_percentage_error: 19.6492
# Epoch 56/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0831 - mean_absolute_percentage_error: 30.2999 - val_loss: 3.4192 - val_mean_absolute_percentage_error: 19.6953
# Epoch 57/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9414 - mean_absolute_percentage_error: 30.0767 - val_loss: 3.4070 - val_mean_absolute_percentage_error: 19.6301
# Epoch 58/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0783 - mean_absolute_percentage_error: 30.1897 - val_loss: 3.4445 - val_mean_absolute_percentage_error: 19.8309
# Epoch 59/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9717 - mean_absolute_percentage_error: 29.8634 - val_loss: 3.3678 - val_mean_absolute_percentage_error: 19.4192
# Epoch 60/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0981 - mean_absolute_percentage_error: 30.2110 - val_loss: 3.2454 - val_mean_absolute_percentage_error: 18.7596
# Epoch 61/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0597 - mean_absolute_percentage_error: 30.0383 - val_loss: 3.3116 - val_mean_absolute_percentage_error: 19.1171
# Epoch 62/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.1119 - mean_absolute_percentage_error: 30.2897 - val_loss: 3.2470 - val_mean_absolute_percentage_error: 18.7681
# Epoch 63/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.1260 - mean_absolute_percentage_error: 30.3323 - val_loss: 3.2248 - val_mean_absolute_percentage_error: 18.6483
# Epoch 64/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0346 - mean_absolute_percentage_error: 29.6552 - val_loss: 3.3021 - val_mean_absolute_percentage_error: 19.0657
# Epoch 65/250
# 18/18 [==============================] - 0s 3ms/step - loss: 8.9800 - mean_absolute_percentage_error: 29.9862 - val_loss: 3.4392 - val_mean_absolute_percentage_error: 19.8025
# Epoch 66/250
# 18/18 [==============================] - 0s 2ms/step - loss: 9.0428 - mean_absolute_percentage_error: 30.1475 - val_loss: 3.4122 - val_mean_absolute_percentage_error: 19.6579
# Epoch 67/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9385 - mean_absolute_percentage_error: 29.8506 - val_loss: 3.5325 - val_mean_absolute_percentage_error: 20.3008
# Epoch 68/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9909 - mean_absolute_percentage_error: 29.9760 - val_loss: 3.4756 - val_mean_absolute_percentage_error: 19.9970
# Epoch 69/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9489 - mean_absolute_percentage_error: 29.6993 - val_loss: 3.3708 - val_mean_absolute_percentage_error: 19.4357
# Epoch 70/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9283 - mean_absolute_percentage_error: 29.4314 - val_loss: 3.3912 - val_mean_absolute_percentage_error: 19.5453
# Epoch 71/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7515 - mean_absolute_percentage_error: 29.0050 - val_loss: 3.5014 - val_mean_absolute_percentage_error: 20.1346
# Epoch 72/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7654 - mean_absolute_percentage_error: 29.0984 - val_loss: 3.3734 - val_mean_absolute_percentage_error: 19.4496
# Epoch 73/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.8471 - mean_absolute_percentage_error: 29.3089 - val_loss: 3.3289 - val_mean_absolute_percentage_error: 19.2100
# Epoch 74/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.8720 - mean_absolute_percentage_error: 29.1733 - val_loss: 3.3895 - val_mean_absolute_percentage_error: 19.5359
# Epoch 75/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6932 - mean_absolute_percentage_error: 28.6057 - val_loss: 3.4086 - val_mean_absolute_percentage_error: 19.6387
# Epoch 76/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9172 - mean_absolute_percentage_error: 29.4343 - val_loss: 3.4470 - val_mean_absolute_percentage_error: 19.8442
# Epoch 77/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7244 - mean_absolute_percentage_error: 28.9222 - val_loss: 3.3890 - val_mean_absolute_percentage_error: 19.5330
# Epoch 78/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6740 - mean_absolute_percentage_error: 28.2556 - val_loss: 3.4017 - val_mean_absolute_percentage_error: 19.6014
# Epoch 79/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6320 - mean_absolute_percentage_error: 28.1580 - val_loss: 3.5556 - val_mean_absolute_percentage_error: 20.4238
# Epoch 80/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5267 - mean_absolute_percentage_error: 28.3150 - val_loss: 3.5634 - val_mean_absolute_percentage_error: 20.4655
# Epoch 81/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7529 - mean_absolute_percentage_error: 29.0911 - val_loss: 3.4201 - val_mean_absolute_percentage_error: 19.7004
# Epoch 82/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5635 - mean_absolute_percentage_error: 28.0917 - val_loss: 3.4258 - val_mean_absolute_percentage_error: 19.7310
# Epoch 83/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7761 - mean_absolute_percentage_error: 28.9358 - val_loss: 3.3933 - val_mean_absolute_percentage_error: 19.5565
# Epoch 84/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7908 - mean_absolute_percentage_error: 28.8955 - val_loss: 3.3986 - val_mean_absolute_percentage_error: 19.5850
# Epoch 85/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4828 - mean_absolute_percentage_error: 27.6962 - val_loss: 3.3538 - val_mean_absolute_percentage_error: 19.3443
# Epoch 86/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6463 - mean_absolute_percentage_error: 28.4167 - val_loss: 3.2674 - val_mean_absolute_percentage_error: 18.8786
# Epoch 87/250
# 18/18 [==============================] - 0s 3ms/step - loss: 8.6579 - mean_absolute_percentage_error: 28.3127 - val_loss: 3.3633 - val_mean_absolute_percentage_error: 19.3950
# Epoch 88/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.7387 - mean_absolute_percentage_error: 28.6037 - val_loss: 3.2645 - val_mean_absolute_percentage_error: 18.8629
# Epoch 89/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4898 - mean_absolute_percentage_error: 27.5983 - val_loss: 3.2499 - val_mean_absolute_percentage_error: 18.7841
# Epoch 90/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5895 - mean_absolute_percentage_error: 28.1358 - val_loss: 3.3056 - val_mean_absolute_percentage_error: 19.0849
# Epoch 91/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6477 - mean_absolute_percentage_error: 28.3448 - val_loss: 3.3524 - val_mean_absolute_percentage_error: 19.3365
# Epoch 92/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5638 - mean_absolute_percentage_error: 28.0649 - val_loss: 3.4253 - val_mean_absolute_percentage_error: 19.7280
# Epoch 93/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6227 - mean_absolute_percentage_error: 28.3080 - val_loss: 3.4215 - val_mean_absolute_percentage_error: 19.7077
# Epoch 94/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.6140 - mean_absolute_percentage_error: 28.3239 - val_loss: 3.3525 - val_mean_absolute_percentage_error: 19.3371
# Epoch 95/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4518 - mean_absolute_percentage_error: 27.4957 - val_loss: 3.3863 - val_mean_absolute_percentage_error: 19.5185
# Epoch 96/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5513 - mean_absolute_percentage_error: 27.9035 - val_loss: 3.4226 - val_mean_absolute_percentage_error: 19.7136
# Epoch 97/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4232 - mean_absolute_percentage_error: 27.5553 - val_loss: 3.5949 - val_mean_absolute_percentage_error: 20.6330
# Epoch 98/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5016 - mean_absolute_percentage_error: 27.8931 - val_loss: 3.4963 - val_mean_absolute_percentage_error: 20.1076
# Epoch 99/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5013 - mean_absolute_percentage_error: 27.7975 - val_loss: 3.4191 - val_mean_absolute_percentage_error: 19.6949
# Epoch 100/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4107 - mean_absolute_percentage_error: 27.4871 - val_loss: 3.4974 - val_mean_absolute_percentage_error: 20.1135
# Epoch 101/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2705 - mean_absolute_percentage_error: 26.9667 - val_loss: 3.5689 - val_mean_absolute_percentage_error: 20.4948
# Epoch 102/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.3263 - mean_absolute_percentage_error: 27.2510 - val_loss: 3.5942 - val_mean_absolute_percentage_error: 20.6293
# Epoch 103/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4058 - mean_absolute_percentage_error: 27.5037 - val_loss: 3.5155 - val_mean_absolute_percentage_error: 20.2098
# Epoch 104/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.3633 - mean_absolute_percentage_error: 27.2815 - val_loss: 3.4494 - val_mean_absolute_percentage_error: 19.8573
# Epoch 105/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.3601 - mean_absolute_percentage_error: 27.0417 - val_loss: 3.4718 - val_mean_absolute_percentage_error: 19.9765
# Epoch 106/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2718 - mean_absolute_percentage_error: 26.8544 - val_loss: 3.4061 - val_mean_absolute_percentage_error: 19.6250
# Epoch 107/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2775 - mean_absolute_percentage_error: 26.7132 - val_loss: 3.2730 - val_mean_absolute_percentage_error: 18.9090
# Epoch 108/250
# 18/18 [==============================] - 0s 3ms/step - loss: 8.1898 - mean_absolute_percentage_error: 26.3160 - val_loss: 3.3098 - val_mean_absolute_percentage_error: 19.1076
# Epoch 109/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2675 - mean_absolute_percentage_error: 26.6677 - val_loss: 3.3912 - val_mean_absolute_percentage_error: 19.5450
# Epoch 110/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1930 - mean_absolute_percentage_error: 26.4829 - val_loss: 3.5054 - val_mean_absolute_percentage_error: 20.1564
# Epoch 111/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.3878 - mean_absolute_percentage_error: 27.3589 - val_loss: 3.4720 - val_mean_absolute_percentage_error: 19.9780
# Epoch 112/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.4396 - mean_absolute_percentage_error: 27.4411 - val_loss: 3.4245 - val_mean_absolute_percentage_error: 19.7240
# Epoch 113/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2873 - mean_absolute_percentage_error: 26.9022 - val_loss: 3.4332 - val_mean_absolute_percentage_error: 19.7707
# Epoch 114/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1971 - mean_absolute_percentage_error: 26.3794 - val_loss: 3.4942 - val_mean_absolute_percentage_error: 20.0964
# Epoch 115/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.0885 - mean_absolute_percentage_error: 26.0379 - val_loss: 3.5833 - val_mean_absolute_percentage_error: 20.5714
# Epoch 116/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1941 - mean_absolute_percentage_error: 26.7198 - val_loss: 3.5520 - val_mean_absolute_percentage_error: 20.4048
# Epoch 117/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1754 - mean_absolute_percentage_error: 26.4581 - val_loss: 3.4516 - val_mean_absolute_percentage_error: 19.8691
# Epoch 118/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2288 - mean_absolute_percentage_error: 26.6607 - val_loss: 3.4031 - val_mean_absolute_percentage_error: 19.6089
# Epoch 119/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1848 - mean_absolute_percentage_error: 26.3535 - val_loss: 3.4878 - val_mean_absolute_percentage_error: 20.0625
# Epoch 120/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.0413 - mean_absolute_percentage_error: 26.0194 - val_loss: 3.6382 - val_mean_absolute_percentage_error: 20.8630
# Epoch 121/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2115 - mean_absolute_percentage_error: 26.6547 - val_loss: 3.4601 - val_mean_absolute_percentage_error: 19.9144
# Epoch 122/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.0397 - mean_absolute_percentage_error: 25.6292 - val_loss: 3.4635 - val_mean_absolute_percentage_error: 19.9326
# Epoch 123/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9726 - mean_absolute_percentage_error: 25.5673 - val_loss: 3.5179 - val_mean_absolute_percentage_error: 20.2229
# Epoch 124/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.2143 - mean_absolute_percentage_error: 26.5724 - val_loss: 3.4304 - val_mean_absolute_percentage_error: 19.7556
# Epoch 125/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1165 - mean_absolute_percentage_error: 26.0055 - val_loss: 3.5136 - val_mean_absolute_percentage_error: 20.1996
# Epoch 126/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9134 - mean_absolute_percentage_error: 25.4870 - val_loss: 3.6719 - val_mean_absolute_percentage_error: 21.0417
# Epoch 127/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.0775 - mean_absolute_percentage_error: 26.1343 - val_loss: 3.6918 - val_mean_absolute_percentage_error: 21.1470
# Epoch 128/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.1870 - mean_absolute_percentage_error: 26.4305 - val_loss: 3.5735 - val_mean_absolute_percentage_error: 20.5193
# Epoch 129/250
# 18/18 [==============================] - 0s 3ms/step - loss: 7.9965 - mean_absolute_percentage_error: 25.5346 - val_loss: 3.5874 - val_mean_absolute_percentage_error: 20.5933
# Epoch 130/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9771 - mean_absolute_percentage_error: 25.4504 - val_loss: 3.5886 - val_mean_absolute_percentage_error: 20.5994
# Epoch 131/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9954 - mean_absolute_percentage_error: 25.8415 - val_loss: 3.6916 - val_mean_absolute_percentage_error: 21.1460
# Epoch 132/250
# 18/18 [==============================] - 0s 2ms/step - loss: 8.0469 - mean_absolute_percentage_error: 25.9822 - val_loss: 3.7241 - val_mean_absolute_percentage_error: 21.3181
# Epoch 133/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9412 - mean_absolute_percentage_error: 25.5071 - val_loss: 3.5372 - val_mean_absolute_percentage_error: 20.3258
# Epoch 134/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8894 - mean_absolute_percentage_error: 25.1256 - val_loss: 3.5238 - val_mean_absolute_percentage_error: 20.2543
# Epoch 135/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9004 - mean_absolute_percentage_error: 25.2939 - val_loss: 3.7461 - val_mean_absolute_percentage_error: 21.4340
# Epoch 136/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9152 - mean_absolute_percentage_error: 25.5652 - val_loss: 3.6811 - val_mean_absolute_percentage_error: 21.0907
# Epoch 137/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8006 - mean_absolute_percentage_error: 24.8582 - val_loss: 3.6234 - val_mean_absolute_percentage_error: 20.7844
# Epoch 138/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8139 - mean_absolute_percentage_error: 24.9327 - val_loss: 3.7909 - val_mean_absolute_percentage_error: 21.6704
# Epoch 139/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7883 - mean_absolute_percentage_error: 25.0772 - val_loss: 3.7714 - val_mean_absolute_percentage_error: 21.5679
# Epoch 140/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8740 - mean_absolute_percentage_error: 25.1743 - val_loss: 3.6534 - val_mean_absolute_percentage_error: 20.9435
# Epoch 141/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8171 - mean_absolute_percentage_error: 25.0034 - val_loss: 3.5793 - val_mean_absolute_percentage_error: 20.5501
# Epoch 142/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7756 - mean_absolute_percentage_error: 24.7441 - val_loss: 3.5891 - val_mean_absolute_percentage_error: 20.6018
# Epoch 143/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7717 - mean_absolute_percentage_error: 24.6971 - val_loss: 3.7058 - val_mean_absolute_percentage_error: 21.2212
# Epoch 144/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7261 - mean_absolute_percentage_error: 24.8180 - val_loss: 4.0390 - val_mean_absolute_percentage_error: 22.9751
# Epoch 145/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7552 - mean_absolute_percentage_error: 24.8908 - val_loss: 3.8446 - val_mean_absolute_percentage_error: 21.9537
# Epoch 146/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6908 - mean_absolute_percentage_error: 24.6038 - val_loss: 3.7141 - val_mean_absolute_percentage_error: 21.2652
# Epoch 147/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7352 - mean_absolute_percentage_error: 24.7388 - val_loss: 3.7254 - val_mean_absolute_percentage_error: 21.3247
# Epoch 148/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8216 - mean_absolute_percentage_error: 24.9425 - val_loss: 3.5379 - val_mean_absolute_percentage_error: 20.3296
# Epoch 149/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7132 - mean_absolute_percentage_error: 24.5417 - val_loss: 3.7734 - val_mean_absolute_percentage_error: 21.5785
# Epoch 150/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7758 - mean_absolute_percentage_error: 24.9043 - val_loss: 3.6009 - val_mean_absolute_percentage_error: 20.6650
# Epoch 151/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6863 - mean_absolute_percentage_error: 24.3467 - val_loss: 3.6343 - val_mean_absolute_percentage_error: 20.8424
# Epoch 152/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7233 - mean_absolute_percentage_error: 24.6455 - val_loss: 3.7214 - val_mean_absolute_percentage_error: 21.3036
# Epoch 153/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7134 - mean_absolute_percentage_error: 24.4776 - val_loss: 3.7059 - val_mean_absolute_percentage_error: 21.2218
# Epoch 154/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7070 - mean_absolute_percentage_error: 24.5866 - val_loss: 3.8418 - val_mean_absolute_percentage_error: 21.9392
# Epoch 155/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6837 - mean_absolute_percentage_error: 24.4678 - val_loss: 3.6755 - val_mean_absolute_percentage_error: 21.0609
# Epoch 156/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6151 - mean_absolute_percentage_error: 24.1669 - val_loss: 3.7471 - val_mean_absolute_percentage_error: 21.4395
# Epoch 157/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6200 - mean_absolute_percentage_error: 24.2981 - val_loss: 3.7639 - val_mean_absolute_percentage_error: 21.5282
# Epoch 158/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6301 - mean_absolute_percentage_error: 24.1964 - val_loss: 3.6998 - val_mean_absolute_percentage_error: 21.1896
# Epoch 159/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6338 - mean_absolute_percentage_error: 24.2457 - val_loss: 3.7382 - val_mean_absolute_percentage_error: 21.3923
# Epoch 160/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7001 - mean_absolute_percentage_error: 24.5638 - val_loss: 3.5122 - val_mean_absolute_percentage_error: 20.1924
# Epoch 161/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5748 - mean_absolute_percentage_error: 23.7709 - val_loss: 3.4993 - val_mean_absolute_percentage_error: 20.1237
# Epoch 162/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6594 - mean_absolute_percentage_error: 24.2353 - val_loss: 3.6536 - val_mean_absolute_percentage_error: 20.9449
# Epoch 163/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6563 - mean_absolute_percentage_error: 24.2580 - val_loss: 3.7072 - val_mean_absolute_percentage_error: 21.2285
# Epoch 164/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6010 - mean_absolute_percentage_error: 24.3054 - val_loss: 3.9060 - val_mean_absolute_percentage_error: 22.2769
# Epoch 165/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6191 - mean_absolute_percentage_error: 24.4438 - val_loss: 3.8103 - val_mean_absolute_percentage_error: 21.7731
# Epoch 166/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6306 - mean_absolute_percentage_error: 24.1744 - val_loss: 3.6547 - val_mean_absolute_percentage_error: 20.9505
# Epoch 167/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6074 - mean_absolute_percentage_error: 24.0372 - val_loss: 3.4674 - val_mean_absolute_percentage_error: 19.9531
# Epoch 168/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5568 - mean_absolute_percentage_error: 23.7997 - val_loss: 3.7033 - val_mean_absolute_percentage_error: 21.2081
# Epoch 169/250
# 18/18 [==============================] - 0s 3ms/step - loss: 7.5150 - mean_absolute_percentage_error: 23.7373 - val_loss: 3.7318 - val_mean_absolute_percentage_error: 21.3587
# Epoch 170/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4556 - mean_absolute_percentage_error: 23.4268 - val_loss: 3.7655 - val_mean_absolute_percentage_error: 21.5365
# Epoch 171/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5322 - mean_absolute_percentage_error: 23.8181 - val_loss: 3.6540 - val_mean_absolute_percentage_error: 20.9470
# Epoch 172/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.6285 - mean_absolute_percentage_error: 24.0711 - val_loss: 3.6352 - val_mean_absolute_percentage_error: 20.8470
# Epoch 173/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5350 - mean_absolute_percentage_error: 23.8903 - val_loss: 3.7260 - val_mean_absolute_percentage_error: 21.3282
# Epoch 174/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5328 - mean_absolute_percentage_error: 23.7094 - val_loss: 3.6412 - val_mean_absolute_percentage_error: 20.8790
# Epoch 175/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5102 - mean_absolute_percentage_error: 23.6224 - val_loss: 3.7742 - val_mean_absolute_percentage_error: 21.5828
# Epoch 176/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4524 - mean_absolute_percentage_error: 23.4886 - val_loss: 3.8024 - val_mean_absolute_percentage_error: 21.7315
# Epoch 177/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4672 - mean_absolute_percentage_error: 23.6975 - val_loss: 3.8821 - val_mean_absolute_percentage_error: 22.1513
# Epoch 178/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5300 - mean_absolute_percentage_error: 24.0858 - val_loss: 3.9740 - val_mean_absolute_percentage_error: 22.6342
# Epoch 179/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4381 - mean_absolute_percentage_error: 23.4929 - val_loss: 3.6126 - val_mean_absolute_percentage_error: 20.7271
# Epoch 180/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5066 - mean_absolute_percentage_error: 23.7396 - val_loss: 3.7357 - val_mean_absolute_percentage_error: 21.3791
# Epoch 181/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4175 - mean_absolute_percentage_error: 23.4637 - val_loss: 3.8146 - val_mean_absolute_percentage_error: 21.7955
# Epoch 182/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4482 - mean_absolute_percentage_error: 23.5885 - val_loss: 3.8818 - val_mean_absolute_percentage_error: 22.1496
# Epoch 183/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.5162 - mean_absolute_percentage_error: 23.9297 - val_loss: 3.9271 - val_mean_absolute_percentage_error: 22.3881
# Epoch 184/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4469 - mean_absolute_percentage_error: 23.6071 - val_loss: 3.8022 - val_mean_absolute_percentage_error: 21.7303
# Epoch 185/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3881 - mean_absolute_percentage_error: 23.2319 - val_loss: 3.7457 - val_mean_absolute_percentage_error: 21.4322
# Epoch 186/250
# 18/18 [==============================] - 0s 3ms/step - loss: 7.4218 - mean_absolute_percentage_error: 23.5303 - val_loss: 3.8828 - val_mean_absolute_percentage_error: 22.1548
# Epoch 187/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4416 - mean_absolute_percentage_error: 23.5812 - val_loss: 3.7984 - val_mean_absolute_percentage_error: 21.7100
# Epoch 188/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4368 - mean_absolute_percentage_error: 23.5416 - val_loss: 3.7564 - val_mean_absolute_percentage_error: 21.4884
# Epoch 189/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3537 - mean_absolute_percentage_error: 23.1509 - val_loss: 3.8153 - val_mean_absolute_percentage_error: 21.7996
# Epoch 190/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4210 - mean_absolute_percentage_error: 23.6949 - val_loss: 4.0168 - val_mean_absolute_percentage_error: 22.8590
# Epoch 191/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3590 - mean_absolute_percentage_error: 23.2811 - val_loss: 3.8498 - val_mean_absolute_percentage_error: 21.9810
# Epoch 192/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3745 - mean_absolute_percentage_error: 23.2506 - val_loss: 3.7873 - val_mean_absolute_percentage_error: 21.6515
# Epoch 193/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3932 - mean_absolute_percentage_error: 23.4417 - val_loss: 4.0144 - val_mean_absolute_percentage_error: 22.8465
# Epoch 194/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3574 - mean_absolute_percentage_error: 23.4935 - val_loss: 4.0306 - val_mean_absolute_percentage_error: 22.9314
# Epoch 195/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3491 - mean_absolute_percentage_error: 23.2879 - val_loss: 3.9089 - val_mean_absolute_percentage_error: 22.2924
# Epoch 196/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3447 - mean_absolute_percentage_error: 23.0920 - val_loss: 3.8118 - val_mean_absolute_percentage_error: 21.7806
# Epoch 197/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4013 - mean_absolute_percentage_error: 23.4092 - val_loss: 3.7833 - val_mean_absolute_percentage_error: 21.6306
# Epoch 198/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3359 - mean_absolute_percentage_error: 23.0457 - val_loss: 3.8604 - val_mean_absolute_percentage_error: 22.0369
# Epoch 199/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3919 - mean_absolute_percentage_error: 23.4386 - val_loss: 3.9394 - val_mean_absolute_percentage_error: 22.4526
# Epoch 200/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3613 - mean_absolute_percentage_error: 23.2161 - val_loss: 3.8420 - val_mean_absolute_percentage_error: 21.9400
# Epoch 201/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3549 - mean_absolute_percentage_error: 23.1866 - val_loss: 3.7999 - val_mean_absolute_percentage_error: 21.7180
# Epoch 202/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3591 - mean_absolute_percentage_error: 23.1932 - val_loss: 3.8178 - val_mean_absolute_percentage_error: 21.8125
# Epoch 203/250
# 18/18 [==============================] - 0s 3ms/step - loss: 7.3719 - mean_absolute_percentage_error: 23.1986 - val_loss: 3.8019 - val_mean_absolute_percentage_error: 21.7289
# Epoch 204/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3104 - mean_absolute_percentage_error: 23.0155 - val_loss: 3.8715 - val_mean_absolute_percentage_error: 22.0954
# Epoch 205/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3084 - mean_absolute_percentage_error: 23.1238 - val_loss: 3.9593 - val_mean_absolute_percentage_error: 22.5575
# Epoch 206/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2571 - mean_absolute_percentage_error: 22.9094 - val_loss: 3.9898 - val_mean_absolute_percentage_error: 22.7172
# Epoch 207/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2892 - mean_absolute_percentage_error: 23.0692 - val_loss: 3.9593 - val_mean_absolute_percentage_error: 22.5573
# Epoch 208/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3305 - mean_absolute_percentage_error: 23.1395 - val_loss: 3.8434 - val_mean_absolute_percentage_error: 21.9474
# Epoch 209/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2986 - mean_absolute_percentage_error: 22.9584 - val_loss: 3.9189 - val_mean_absolute_percentage_error: 22.3448
# Epoch 210/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3394 - mean_absolute_percentage_error: 23.0103 - val_loss: 3.8037 - val_mean_absolute_percentage_error: 21.7381
# Epoch 211/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2337 - mean_absolute_percentage_error: 22.6722 - val_loss: 3.9831 - val_mean_absolute_percentage_error: 22.6823
# Epoch 212/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3100 - mean_absolute_percentage_error: 23.2648 - val_loss: 4.0385 - val_mean_absolute_percentage_error: 22.9726
# Epoch 213/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2800 - mean_absolute_percentage_error: 22.9584 - val_loss: 3.8326 - val_mean_absolute_percentage_error: 21.8904
# Epoch 214/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2574 - mean_absolute_percentage_error: 23.0221 - val_loss: 4.0099 - val_mean_absolute_percentage_error: 22.8230
# Epoch 215/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2548 - mean_absolute_percentage_error: 22.9290 - val_loss: 3.8949 - val_mean_absolute_percentage_error: 22.2185
# Epoch 216/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3056 - mean_absolute_percentage_error: 23.0419 - val_loss: 3.8810 - val_mean_absolute_percentage_error: 22.1454
# Epoch 217/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2881 - mean_absolute_percentage_error: 22.9741 - val_loss: 3.9074 - val_mean_absolute_percentage_error: 22.2847
# Epoch 218/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3024 - mean_absolute_percentage_error: 23.0592 - val_loss: 3.9282 - val_mean_absolute_percentage_error: 22.3937
# Epoch 219/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2481 - mean_absolute_percentage_error: 22.8273 - val_loss: 4.0291 - val_mean_absolute_percentage_error: 22.9233
# Epoch 220/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2632 - mean_absolute_percentage_error: 22.9990 - val_loss: 3.9504 - val_mean_absolute_percentage_error: 22.5103
# Epoch 221/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3158 - mean_absolute_percentage_error: 23.0771 - val_loss: 3.9425 - val_mean_absolute_percentage_error: 22.4692
# Epoch 222/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2772 - mean_absolute_percentage_error: 22.9845 - val_loss: 3.9365 - val_mean_absolute_percentage_error: 22.4376
# Epoch 223/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2672 - mean_absolute_percentage_error: 22.9041 - val_loss: 3.9310 - val_mean_absolute_percentage_error: 22.4089
# Epoch 224/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2782 - mean_absolute_percentage_error: 23.0252 - val_loss: 3.8996 - val_mean_absolute_percentage_error: 22.2434
# Epoch 225/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.3020 - mean_absolute_percentage_error: 22.8671 - val_loss: 3.7005 - val_mean_absolute_percentage_error: 21.1935
# Epoch 226/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2393 - mean_absolute_percentage_error: 22.6733 - val_loss: 3.8674 - val_mean_absolute_percentage_error: 22.0738
# Epoch 227/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2558 - mean_absolute_percentage_error: 22.9594 - val_loss: 4.1007 - val_mean_absolute_percentage_error: 23.2987
# Epoch 228/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2089 - mean_absolute_percentage_error: 22.7192 - val_loss: 3.9919 - val_mean_absolute_percentage_error: 22.7285
# Epoch 229/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2308 - mean_absolute_percentage_error: 22.8297 - val_loss: 4.0898 - val_mean_absolute_percentage_error: 23.2416
# Epoch 230/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2484 - mean_absolute_percentage_error: 22.8782 - val_loss: 3.9728 - val_mean_absolute_percentage_error: 22.6284
# Epoch 231/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2293 - mean_absolute_percentage_error: 22.8175 - val_loss: 4.0366 - val_mean_absolute_percentage_error: 22.9628
# Epoch 232/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2191 - mean_absolute_percentage_error: 22.7384 - val_loss: 4.0021 - val_mean_absolute_percentage_error: 22.7818
# Epoch 233/250
# 18/18 [==============================] - 0s 3ms/step - loss: 7.2858 - mean_absolute_percentage_error: 23.1199 - val_loss: 3.9964 - val_mean_absolute_percentage_error: 22.7519
# Epoch 234/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2292 - mean_absolute_percentage_error: 22.7356 - val_loss: 3.8707 - val_mean_absolute_percentage_error: 22.0912
# Epoch 235/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2070 - mean_absolute_percentage_error: 22.6540 - val_loss: 4.0040 - val_mean_absolute_percentage_error: 22.7918
# Epoch 236/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2390 - mean_absolute_percentage_error: 22.9194 - val_loss: 3.9970 - val_mean_absolute_percentage_error: 22.7552
# Epoch 237/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2018 - mean_absolute_percentage_error: 22.6790 - val_loss: 4.0947 - val_mean_absolute_percentage_error: 23.2671
# Epoch 238/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2195 - mean_absolute_percentage_error: 22.8719 - val_loss: 4.1159 - val_mean_absolute_percentage_error: 23.3778
# Epoch 239/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.1995 - mean_absolute_percentage_error: 22.8303 - val_loss: 4.0584 - val_mean_absolute_percentage_error: 23.0770
# Epoch 240/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2202 - mean_absolute_percentage_error: 22.8184 - val_loss: 3.9803 - val_mean_absolute_percentage_error: 22.6675
# Epoch 241/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.1891 - mean_absolute_percentage_error: 22.6446 - val_loss: 3.9669 - val_mean_absolute_percentage_error: 22.5970
# Epoch 242/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2234 - mean_absolute_percentage_error: 22.7837 - val_loss: 3.9477 - val_mean_absolute_percentage_error: 22.4963
# Epoch 243/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2501 - mean_absolute_percentage_error: 22.8357 - val_loss: 3.9304 - val_mean_absolute_percentage_error: 22.4057
# Epoch 244/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.1898 - mean_absolute_percentage_error: 22.5581 - val_loss: 3.9615 - val_mean_absolute_percentage_error: 22.5690
# Epoch 245/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2355 - mean_absolute_percentage_error: 22.8544 - val_loss: 3.9530 - val_mean_absolute_percentage_error: 22.5241
# Epoch 246/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2207 - mean_absolute_percentage_error: 22.8044 - val_loss: 3.9924 - val_mean_absolute_percentage_error: 22.7311
# Epoch 247/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2282 - mean_absolute_percentage_error: 22.7728 - val_loss: 3.9455 - val_mean_absolute_percentage_error: 22.4851
# Epoch 248/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.2283 - mean_absolute_percentage_error: 22.8243 - val_loss: 4.0004 - val_mean_absolute_percentage_error: 22.7727
# Epoch 249/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.1876 - mean_absolute_percentage_error: 22.6866 - val_loss: 4.0358 - val_mean_absolute_percentage_error: 22.9584
# Epoch 250/250
# 18/18 [==============================] - 0s 2ms/step - loss: 7.1966 - mean_absolute_percentage_error: 22.6276 - val_loss: 4.0307 - val_mean_absolute_percentage_error: 22.9320

# %%
# Check the dictionary keys
modeling_result=history.history
modeling_result.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
# 7.2 Plot the history of training and validation
training_loss_values=modeling_result['loss']
val_loss_values=modeling_result['val_loss']
epochs=range(1,len(training_loss_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Loss (Root Mean Squared Error,RMSE)',fontsize=20)
plt.title('INTC Training & Validation of Loss Result (DNN-R5-1)',fontsize=20)

plt.plot(epochs, training_loss_values, marker='.',label='Training Loss', color = '#5C8984')
plt.plot(epochs, val_loss_values, marker='.',label='Validation Loss', color = '#C88EA7')
plt.legend(loc=1,fontsize=24)
plt.show()

# %%
# 7.2 Plot the history of training and validation
training_acc_values=modeling_result['mean_absolute_percentage_error']
val_acc_values=modeling_result['val_mean_absolute_percentage_error']
epochs=range(1,len(training_acc_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Mean Absolute Percentage Error, MAPE',fontsize=20)
plt.title('INTC DNN Training & Validation of MAPE Result (DNN-R5-1)',fontsize=20)

plt.plot(epochs, training_acc_values,marker='.',label='Training MAPE', color = '#5C8984')
plt.plot(epochs, val_acc_values,marker='.',label='Validation MAPE', color = '#C88EA7')
plt.legend(loc=1,fontsize=24)
plt.show()

# %% [markdown]
# # Fit the final model with all of the training data

# %%
# X all train data
x_forecast_train=Forecast_train_data.drop(['Date','Close'],axis=1).copy()
# Close all train data
y_forecast_train=Forecast_train_data['Close'].copy()

# %%
# Create the model (Six Hidden)
clear.clear_session()
Fmodel=Sequential()

# First layer
Fmodel.add(Dense(units=100, input_dim=3))
#model.add(Dropout(0.5))

# Hidden layer
Fmodel.add(Dense(units=100, activation='tanh')) # 120, 100
Fmodel.add(Dropout(0.5))
Fmodel.add(Dense(units=100, activation='tanh')) # 120, 100
Fmodel.add(Dropout(0.5))
Fmodel.add(Dense(units=50, activation='tanh'))  # 80, 50
Fmodel.add(Dropout(0.5))
Fmodel.add(Dense(units=50, activation='tanh')) # 80, 50
Fmodel.add(Dropout(0.5))
Fmodel.add(Dense(units=10, activation='tanh')) # 40, 10
Fmodel.add(Dropout(0.5))
Fmodel.add(Dense(units=10, activation='tanh')) # 40, 10
Fmodel.add(Dropout(0.5))

# Output layer
Fmodel.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01, beta_1=0.9, beta_2 = 0.999, epsilon = 1e-8)
Fmodel.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model
Fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               400
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 50)                5050
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_5 (Dense)             (None, 10)                510
#
#  dropout_4 (Dropout)         (None, 10)                0
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dropout_5 (Dropout)         (None, 10)                0
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 28,831
# Trainable params: 28,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create the model (Three Hidden)
clear.clear_session()
Fmodel3=Sequential()

# First layer
Fmodel3.add(Dense(units=100, input_dim=3))
#model.add(Dropout(0.5))

# Hidden layer
Fmodel3.add(Dense(units=100, activation='tanh')) # 120, 100
Fmodel3.add(Dropout(0.5))

Fmodel3.add(Dense(units=50, activation='tanh'))  # 80, 50
Fmodel3.add(Dropout(0.5))

Fmodel3.add(Dense(units=10, activation='tanh')) # 40, 10
Fmodel3.add(Dropout(0.5))


# Output layer
Fmodel3.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01, beta_1=0.9, beta_2 = 0.999, epsilon = 1e-8)
Fmodel3.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model
Fmodel3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               400
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 10)                510
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 16,071
# Trainable params: 16,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Store in the history for more useful information
history=Fmodel3.fit(x_forecast_train, y_forecast_train, epochs=250, batch_size=128,verbose=1)
# Out:
# Epoch 1/250
# 36/36 [==============================] - 0s 960us/step - loss: 21.5804 - mean_absolute_percentage_error: 77.8341
# Epoch 2/250
# 36/36 [==============================] - 0s 851us/step - loss: 17.4128 - mean_absolute_percentage_error: 60.9030
# Epoch 3/250
# 36/36 [==============================] - 0s 904us/step - loss: 13.6499 - mean_absolute_percentage_error: 46.0580
# Epoch 4/250
# 36/36 [==============================] - 0s 921us/step - loss: 11.0000 - mean_absolute_percentage_error: 36.4203
# Epoch 5/250
# 36/36 [==============================] - 0s 930us/step - loss: 9.8202 - mean_absolute_percentage_error: 32.9633
# Epoch 6/250
# 36/36 [==============================] - 0s 1ms/step - loss: 9.1343 - mean_absolute_percentage_error: 31.4100
# Epoch 7/250
# 36/36 [==============================] - 0s 976us/step - loss: 8.9815 - mean_absolute_percentage_error: 31.2876
# Epoch 8/250
# 36/36 [==============================] - 0s 903us/step - loss: 8.9547 - mean_absolute_percentage_error: 31.7714
# Epoch 9/250
# 36/36 [==============================] - 0s 2ms/step - loss: 8.8187 - mean_absolute_percentage_error: 31.3418
# Epoch 10/250
# 36/36 [==============================] - 0s 904us/step - loss: 8.8063 - mean_absolute_percentage_error: 31.4189
# Epoch 11/250
# 36/36 [==============================] - 0s 900us/step - loss: 8.7880 - mean_absolute_percentage_error: 31.2586
# Epoch 12/250
# 36/36 [==============================] - 0s 902us/step - loss: 8.9141 - mean_absolute_percentage_error: 31.6287
# Epoch 13/250
# 36/36 [==============================] - 0s 905us/step - loss: 8.7443 - mean_absolute_percentage_error: 31.3530
# Epoch 14/250
# 36/36 [==============================] - 0s 907us/step - loss: 8.8130 - mean_absolute_percentage_error: 31.5841
# Epoch 15/250
# 36/36 [==============================] - 0s 907us/step - loss: 8.8034 - mean_absolute_percentage_error: 31.3822
# Epoch 16/250
# 36/36 [==============================] - 0s 904us/step - loss: 8.6724 - mean_absolute_percentage_error: 30.9180
# Epoch 17/250
# 36/36 [==============================] - 0s 897us/step - loss: 8.7796 - mean_absolute_percentage_error: 31.2739
# Epoch 18/250
# 36/36 [==============================] - 0s 914us/step - loss: 8.8346 - mean_absolute_percentage_error: 31.6276
# Epoch 19/250
# 36/36 [==============================] - 0s 914us/step - loss: 8.6453 - mean_absolute_percentage_error: 31.1565
# Epoch 20/250
# 36/36 [==============================] - 0s 913us/step - loss: 8.5251 - mean_absolute_percentage_error: 30.5221
# Epoch 21/250
# 36/36 [==============================] - 0s 911us/step - loss: 8.6387 - mean_absolute_percentage_error: 30.5549
# Epoch 22/250
# 36/36 [==============================] - 0s 921us/step - loss: 8.5976 - mean_absolute_percentage_error: 30.4710
# Epoch 23/250
# 36/36 [==============================] - 0s 903us/step - loss: 8.5871 - mean_absolute_percentage_error: 30.4174
250
# 36/36 [==============================] - 0s 900us/step - loss: 6.5512 - mean_absolute_percentage_error: 22.6192
# Epoch 234/250
# 36/36 [==============================] - 0s 909us/step - loss: 6.5465 - mean_absolute_percentage_error: 22.4765
# Epoch 235/250
# 36/36 [==============================] - 0s 902us/step - loss: 6.5460 - mean_absolute_percentage_error: 22.6374
# Epoch 236/250
# 36/36 [==============================] - 0s 894us/step - loss: 6.5457 - mean_absolute_percentage_error: 22.5086
# Epoch 237/250
# 36/36 [==============================] - 0s 893us/step - loss: 6.5438 - mean_absolute_percentage_error: 22.5837
# Epoch 238/250
# 36/36 [==============================] - 0s 909us/step - loss: 6.5453 - mean_absolute_percentage_error: 22.5897
# Epoch 239/250
# 36/36 [==============================] - 0s 900us/step - loss: 6.5426 - mean_absolute_percentage_error: 22.4094
# Epoch 240/250
# 36/36 [==============================] - 0s 896us/step - loss: 6.5463 - mean_absolute_percentage_error: 22.5533
# Epoch 241/250
# 36/36 [==============================] - 0s 913us/step - loss: 6.5427 - mean_absolute_percentage_error: 22.5693
# Epoch 242/250
# 36/36 [==============================] - 0s 890us/step - loss: 6.5502 - mean_absolute_percentage_error: 22.5773
# Epoch 243/250
# 36/36 [==============================] - 0s 2ms/step - loss: 6.5441 - mean_absolute_percentage_error: 22.5765
# Epoch 244/250
# 36/36 [==============================] - 0s 919us/step - loss: 6.5461 - mean_absolute_percentage_error: 22.5961
# Epoch 245/250
# 36/36 [==============================] - 0s 904us/step - loss: 6.5529 - mean_absolute_percentage_error: 22.3505
# Epoch 246/250
# 36/36 [==============================] - 0s 891us/step - loss: 6.5501 - mean_absolute_percentage_error: 22.7720
# Epoch 247/250
# 36/36 [==============================] - 0s 891us/step - loss: 6.5464 - mean_absolute_percentage_error: 22.4515
# Epoch 248/250
# 36/36 [==============================] - 0s 889us/step - loss: 6.5495 - mean_absolute_percentage_error: 22.5568
# Epoch 249/250
# 36/36 [==============================] - 0s 886us/step - loss: 6.5487 - mean_absolute_percentage_error: 22.7767
# Epoch 250/250
# 36/36 [==============================] - 0s 908us/step - loss: 6.5480 - mean_absolute_percentage_error: 22.3800

# %%
# 7.3 Save the trained model
#Fmodel.save('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
#Fmodel.save('INTC STOCK DNN_trained_model.h5')
Fmodel3.save('INTC STOCK DNN_trained_model.h5')
print('Model has been saved...')
# Out:
# Model has been saved...

# %%
# 7.4 Restore the saved model for testing
#ANN_model=keras.models.load_model('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
ANN_model=keras.models.load_model('INTC STOCK DNN_trained_model.h5')
print('Model successfully loaded...')
# Out:
# Model successfully loaded...

# %% [markdown]
# # 8. Testing

# %%
# X test
x_forecast_test=Forecast_test_data.drop(['Date','Close'],axis=1).copy()
# Close test
y_forecast_test=Forecast_test_data['Close'].copy()

# %%
# 8.1 Make prediction
prediction=np.round((ANN_model.predict_on_batch(x_forecast_test)),2)
pred_values=[]
for i in range(0,len(prediction)):
    value=prediction[i][0]
    pred_values.append(value)

# %%
Results=pd.DataFrame({'Date':Forecast_test_data['Date'],'Close_true':Forecast_test_data['Close'],'Predict':pred_values})
Results['abs Error']=np.abs(Results['Close_true']-Results['Predict'])
Results
# Out:
#            Date  Close_true  Predict  abs Error
# 4525 2018-01-02   46.849998    24.73  22.119998
# 4526 2018-01-03   45.259998    24.73  20.529998
# 4527 2018-01-04   44.430000    24.73  19.700000
# 4528 2018-01-05   44.740002    24.73  20.010002
# 4529 2018-01-08   44.740002    24.73  20.010002
# ...         ...         ...      ...        ...
# 5882 2023-05-24   29.000000    24.73   4.270000
# 5883 2023-05-25   27.400000    24.73   2.670000
# 5884 2023-05-26   29.000000    24.73   4.270000
# 5885 2023-05-30   29.990000    24.73   5.260000
# 5886 2023-05-31   31.440001    24.73   6.710001
#
# [1362 rows x 4 columns]

# %%
# 8.2 Calculating the mertics
MAE=mean_absolute_error(y_forecast_test,pred_values)
MSE=mean_squared_error(y_forecast_test,pred_values,squared=True)
RMSE=mean_squared_error(y_forecast_test,pred_values,squared=False)
MAPE=mean_absolute_percentage_error(y_forecast_test,pred_values)
SMAPE=SMAPE_calulate(y_forecast_test,pred_values)
RAE=RAE_calculate(y_forecast_test,pred_values)
MRAE=MRAE_calculate(y_forecast_test,pred_values)
MdRAE=MdRAE_calculate(y_forecast_test,pred_values)
RSE=RSE_calculate(y_forecast_test,pred_values,Root=False)
RRSE=RSE_calculate(y_forecast_test,pred_values,Root=True)

print('MAE:',round(MAE,3))
print('MSE:',round(MSE,3))
print('RMSE:',round(RMSE,3))
print('MAPE:',round(MAPE*100,3),'%')
print('SMAPE:',round(SMAPE,3),'%')
print('RAE:',round(RAE,3))
print('MRAE:',MRAE)
print('MdRAE:',round(MdRAE[0],3),'bench:',round(MdRAE[1],3))
print('RSE:',round(RSE,3))
print('RRSE:',round(RRSE,3))
# Out:
# MAE: 23.668
# MSE: 657.592
# RMSE: 25.644
# MAPE: 46.047 %
# SMAPE: 61.846 %
# RAE: 3.182
# MRAE: 0.0023359901900995555
# MdRAE: 5.218 bench: 48.398
# RSE: 6.751
# RRSE: 2.598

# %% [markdown]
# #  Plot for comparing true value & predicted value

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('Relative INTC CLOSE Forecast Comparison (2000-2023) (DNN-R5-1)',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('INTC CLOSE',fontsize=18,weight='bold')

# Comparison of actual value and predicted value according to Date
plt.plot(clean_df.iloc[189:,0],clean_df.iloc[189:,1],marker='o',color='blue',label='Actual')
plt.plot(Results['Date'],Results['Predict'],marker='o',color='red',label='Forecast')

# Set the axis
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Set legends
plt.legend(loc=4,fontsize=20)

plt.show()
